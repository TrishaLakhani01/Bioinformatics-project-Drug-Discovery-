# %% [markdown]
# ##**Comparison of ML algorithms to build regression models of alk inhibitors**

# %% [markdown]
# **Import libraries**

# %%
! pip install lazypredict

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# **
# Load the data set**

# %%
df = pd.read_csv('alk_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# **Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (1960, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (1960, 176)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# **Compare ML algorithms**

# %%
import numpy as np
np.random.seed(100)

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
train, test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:33<00:00,  1.27it/s]

# %%
# Performance table of the training set (80% subset)
train
# Out:
#                                        Adjusted R-Squared  \
# Model
# LGBMRegressor                                        0.36
# HistGradientBoostingRegressor                        0.36
# RandomForestRegressor                                0.33
# MLPRegressor                                         0.32
# NuSVR                                                0.28
# SVR                                                  0.28
# XGBRegressor                                         0.28
# GradientBoostingRegressor                            0.23
# BaggingRegressor                                     0.22
# KNeighborsRegressor                                  0.21
# Ridge                                                0.15
# TransformedTargetRegressor                           0.15
# LinearRegression                                     0.15
# RidgeCV                                              0.13
# SGDRegressor                                         0.12
# ElasticNetCV                                         0.11
# LassoCV                                              0.11
# BayesianRidge                                        0.10
# PoissonRegressor                                     0.06
# HuberRegressor                                       0.06
# LinearSVR                                            0.01
# GammaRegressor                                      -0.06
# GeneralizedLinearRegressor                          -0.07
# TweedieRegressor                                    -0.07
# ExtraTreesRegressor                                 -0.11
# OrthogonalMatchingPursuit                           -0.13
# OrthogonalMatchingPursuitCV                         -0.13
# DecisionTreeRegressor                               -0.14
# ExtraTreeRegressor                                  -0.16
# LarsCV                                              -0.18
# AdaBoostRegressor                                   -0.18
# LassoLarsIC                                         -0.19
# LassoLarsCV                                         -0.19
# PassiveAggressiveRegressor                          -0.54
# Lasso                                               -0.85
# ElasticNet                                          -0.85
# DummyRegressor                                      -0.85
# LassoLars                                           -0.85
# GaussianProcessRegressor                           -29.70
# KernelRidge                                        -44.17
# Lars                                             -1755.75
# RANSACRegressor               -18215713488306966626304.00
#
#                                                 R-Squared            RMSE  \
# Model
# LGBMRegressor                                        0.65            0.83
# HistGradientBoostingRegressor                        0.65            0.83
# RandomForestRegressor                                0.63            0.85
# MLPRegressor                                         0.63            0.85
# NuSVR                                                0.61            0.88
# SVR                                                  0.61            0.88
# XGBRegressor                                         0.60            0.88
# GradientBoostingRegressor                            0.58            0.91
# BaggingRegressor                                     0.57            0.91
# KNeighborsRegressor                                  0.57            0.92
# Ridge                                                0.53            0.95
# TransformedTargetRegressor                           0.53            0.96
# LinearRegression                                     0.53            0.96
# RidgeCV                                              0.52            0.97
# SGDRegressor                                         0.52            0.97
# ElasticNetCV                                         0.51            0.98
# LassoCV                                              0.51            0.98
# BayesianRidge                                        0.51            0.98
# PoissonRegressor                                     0.49            1.00
# HuberRegressor                                       0.48            1.01
# LinearSVR                                            0.46            1.03
# GammaRegressor                                       0.42            1.07
# GeneralizedLinearRegressor                           0.41            1.07
# TweedieRegressor                                     0.41            1.07
# ExtraTreesRegressor                                  0.39            1.09
# OrthogonalMatchingPursuit                            0.38            1.10
# OrthogonalMatchingPursuitCV                          0.38            1.10
# DecisionTreeRegressor                                0.37            1.11
# ExtraTreeRegressor                                   0.36            1.12
# LarsCV                                               0.35            1.13
# AdaBoostRegressor                                    0.35            1.13
# LassoLarsIC                                          0.34            1.13
# LassoLarsCV                                          0.34            1.13
# PassiveAggressiveRegressor                           0.15            1.29
# Lasso                                               -0.02            1.41
# ElasticNet                                          -0.02            1.41
# DummyRegressor                                      -0.02            1.41
# LassoLars                                           -0.02            1.41
# GaussianProcessRegressor                           -15.88            5.74
# KernelRidge                                        -23.84            6.97
# Lars                                              -964.99           43.45
# RANSACRegressor               -10016313043442450038784.00 139899912463.68
#
#                                Time Taken
# Model
# LGBMRegressor                        0.28
# HistGradientBoostingRegressor        3.60
# RandomForestRegressor                2.48
# MLPRegressor                         3.18
# NuSVR                                0.80
# SVR                                  0.98
# XGBRegressor                         1.20
# GradientBoostingRegressor            0.91
# BaggingRegressor                     0.33
# KNeighborsRegressor                  0.32
# Ridge                                0.04
# TransformedTargetRegressor           0.05
# LinearRegression                     0.10
# RidgeCV                              0.11
# SGDRegressor                         0.13
# ElasticNetCV                         4.07
# LassoCV                              4.15
# BayesianRidge                        0.10
# PoissonRegressor                     0.08
# HuberRegressor                       0.44
# LinearSVR                            0.53
# GammaRegressor                       0.05
# GeneralizedLinearRegressor           0.05
# TweedieRegressor                     0.05
# ExtraTreesRegressor                  3.97
# OrthogonalMatchingPursuit            0.04
# OrthogonalMatchingPursuitCV          0.11
# DecisionTreeRegressor                0.13
# ExtraTreeRegressor                   0.17
# LarsCV                               0.61
# AdaBoostRegressor                    0.69
# LassoLarsIC                          0.06
# LassoLarsCV                          0.26
# PassiveAggressiveRegressor           0.08
# Lasso                                0.05
# ElasticNet                           0.10
# DummyRegressor                       0.03
# LassoLars                            0.09
# GaussianProcessRegressor             0.77
# KernelRidge                          0.23
# Lars                                 0.17
# RANSACRegressor                      1.32

# %%
# Performance table of the test set (20% subset)
test
# Out:
#                                        Adjusted R-Squared  \
# Model
# LGBMRegressor                                        0.36
# HistGradientBoostingRegressor                        0.36
# RandomForestRegressor                                0.33
# MLPRegressor                                         0.32
# NuSVR                                                0.28
# SVR                                                  0.28
# XGBRegressor                                         0.28
# GradientBoostingRegressor                            0.23
# BaggingRegressor                                     0.22
# KNeighborsRegressor                                  0.21
# Ridge                                                0.15
# TransformedTargetRegressor                           0.15
# LinearRegression                                     0.15
# RidgeCV                                              0.13
# SGDRegressor                                         0.12
# ElasticNetCV                                         0.11
# LassoCV                                              0.11
# BayesianRidge                                        0.10
# PoissonRegressor                                     0.06
# HuberRegressor                                       0.06
# LinearSVR                                            0.01
# GammaRegressor                                      -0.06
# GeneralizedLinearRegressor                          -0.07
# TweedieRegressor                                    -0.07
# ExtraTreesRegressor                                 -0.11
# OrthogonalMatchingPursuit                           -0.13
# OrthogonalMatchingPursuitCV                         -0.13
# DecisionTreeRegressor                               -0.14
# ExtraTreeRegressor                                  -0.16
# LarsCV                                              -0.18
# AdaBoostRegressor                                   -0.18
# LassoLarsIC                                         -0.19
# LassoLarsCV                                         -0.19
# PassiveAggressiveRegressor                          -0.54
# Lasso                                               -0.85
# ElasticNet                                          -0.85
# DummyRegressor                                      -0.85
# LassoLars                                           -0.85
# GaussianProcessRegressor                           -29.70
# KernelRidge                                        -44.17
# Lars                                             -1755.75
# RANSACRegressor               -18215713488306966626304.00
#
#                                                 R-Squared            RMSE  \
# Model
# LGBMRegressor                                        0.65            0.83
# HistGradientBoostingRegressor                        0.65            0.83
# RandomForestRegressor                                0.63            0.85
# MLPRegressor                                         0.63            0.85
# NuSVR                                                0.61            0.88
# SVR                                                  0.61            0.88
# XGBRegressor                                         0.60            0.88
# GradientBoostingRegressor                            0.58            0.91
# BaggingRegressor                                     0.57            0.91
# KNeighborsRegressor                                  0.57            0.92
# Ridge                                                0.53            0.95
# TransformedTargetRegressor                           0.53            0.96
# LinearRegression                                     0.53            0.96
# RidgeCV                                              0.52            0.97
# SGDRegressor                                         0.52            0.97
# ElasticNetCV                                         0.51            0.98
# LassoCV                                              0.51            0.98
# BayesianRidge                                        0.51            0.98
# PoissonRegressor                                     0.49            1.00
# HuberRegressor                                       0.48            1.01
# LinearSVR                                            0.46            1.03
# GammaRegressor                                       0.42            1.07
# GeneralizedLinearRegressor                           0.41            1.07
# TweedieRegressor                                     0.41            1.07
# ExtraTreesRegressor                                  0.39            1.09
# OrthogonalMatchingPursuit                            0.38            1.10
# OrthogonalMatchingPursuitCV                          0.38            1.10
# DecisionTreeRegressor                                0.37            1.11
# ExtraTreeRegressor                                   0.36            1.12
# LarsCV                                               0.35            1.13
# AdaBoostRegressor                                    0.35            1.13
# LassoLarsIC                                          0.34            1.13
# LassoLarsCV                                          0.34            1.13
# PassiveAggressiveRegressor                           0.15            1.29
# Lasso                                               -0.02            1.41
# ElasticNet                                          -0.02            1.41
# DummyRegressor                                      -0.02            1.41
# LassoLars                                           -0.02            1.41
# GaussianProcessRegressor                           -15.88            5.74
# KernelRidge                                        -23.84            6.97
# Lars                                              -964.99           43.45
# RANSACRegressor               -10016313043442450038784.00 139899912463.68
#
#                                Time Taken
# Model
# LGBMRegressor                        0.28
# HistGradientBoostingRegressor        3.60
# RandomForestRegressor                2.48
# MLPRegressor                         3.18
# NuSVR                                0.80
# SVR                                  0.98
# XGBRegressor                         1.20
# GradientBoostingRegressor            0.91
# BaggingRegressor                     0.33
# KNeighborsRegressor                  0.32
# Ridge                                0.04
# TransformedTargetRegressor           0.05
# LinearRegression                     0.10
# RidgeCV                              0.11
# SGDRegressor                         0.13
# ElasticNetCV                         4.07
# LassoCV                              4.15
# BayesianRidge                        0.10
# PoissonRegressor                     0.08
# HuberRegressor                       0.44
# LinearSVR                            0.53
# GammaRegressor                       0.05
# GeneralizedLinearRegressor           0.05
# TweedieRegressor                     0.05
# ExtraTreesRegressor                  3.97
# OrthogonalMatchingPursuit            0.04
# OrthogonalMatchingPursuitCV          0.11
# DecisionTreeRegressor                0.13
# ExtraTreeRegressor                   0.17
# LarsCV                               0.61
# AdaBoostRegressor                    0.69
# LassoLarsIC                          0.06
# LassoLarsCV                          0.26
# PassiveAggressiveRegressor           0.08
# Lasso                                0.05
# ElasticNet                           0.10
# DummyRegressor                       0.03
# LassoLars                            0.09
# GaussianProcessRegressor             0.77
# KernelRidge                          0.23
# Lars                                 0.17
# RANSACRegressor                      1.32

# %% [markdown]
# **Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="R-Squared", data=train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="RMSE", data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="Time Taken", data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
